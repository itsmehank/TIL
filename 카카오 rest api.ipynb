# %% [markdown]
# ## 카카오 api 사용 방법
#
# 사용방법: https://blankspace-dev.tistory.com/422
#
# api 키 확인 페이지(로그인필요) : https://developers.kakao.com/apps/360756/settings/general

# %%
import requests
import datetime
import json

fore_url = 'https://dapi.kakao.com/v2/local/search/address.json'

# fore_key = "Vm3Kb2StjrahNTDhP8MchJI84d8oUBQEZkaqSgiOHX2RQO6nEpcXq31OvP4U1UIcgAO2igNI7R375ZjRF%2BF0PA%3D%3D"
# fore_key = requests.utils.unquote(fore_key)
# fore_key


address = "서울 마포구 마포동"

header = {"Authorization": "KakaoAK 5ea85a4b65d4072f445cda7ee23daf8b"}

params = {
    "query": address
}


r = requests.get(fore_url,headers = header, params = params)

# python_html = requests.get(fore_url, params = params).json()

print(type(r.json()))

r.json()

# python_html = python_html['response']['body']['items']['item']



          
# print(f"[   발표 날짜 {python_html[0]['baseDate']}   ]")  
# print(f"[   발표 시간 {python_html[0]['baseTime']}   ]")
# print("[   초단기 일기 예보 입니다   ]")
      
      
      
# for k in range(len(python_html)):
#     if python_html[k]['category'] in Categort_list:
#           print("\n-----------------------------")
#           print(f"예측 일자,시간 : {python_html[k]['fcstDate']}  {python_html[k]['fcstTime']}")
#     if python_html[k]['category'] == 'LGT':
#           if python_html[k]['fcstValue'] == 0:
#               print("* 낙뢰는 없습니다.")
#           else:
#               print("* 낙뢰를 맞을 가능성이 있습니다. 주의하세요.")
#     if python_html[k]['category'] == 'PTY':
#           print("강수 & 강우 관련: " + PTY_list[python_html[k]['fcstValue']])
#     if python_html[k]['category'] == 'RN1':
#           print("한 시간동안 비는 어느정도 올까요?   정답은: " + RN1_dict[python_html[k]['fcstValue']])
#     if python_html[k]['category'] == 'SKY':
#           print("하늘 상태는 다음과 같습니다 : "+ SKY_dict[python_html[k]['fcstValue']])
#     if python_html[k]['category'] == 'T1H':
#           print(f"기온은 섭씨 {python_html[k]['fcstValue']}도 입니다.")
#     if python_html[k]['category'] == 'REH':
#           print(f"습도는 {python_html[k]['fcstValue']}퍼센트 입니다.")
#     if python_html[k]['category'] == 'WSD':
#           print(f"풍속은 {python_html[k]['fcstValue']}m/s입니다.")
# Out:
# <class 'dict'>
# {'documents': [{'address': {'address_name': '서울 마포구 마포동',
#     'b_code': '1144010700',
#     'h_code': '',
#     'main_adderss_no': '',
#     'main_address_no': '',
#     'mountain_yn': 'N',
#     'region_1depth_name': '서울',
#     'region_2depth_name': '마포구',
#     'region_3depth_h_name': '',
#     'region_3depth_name': '마포동',
#     'sub_adderss_no': '',
#     'sub_address_no': '',
#     'x': '126.94382545190385',
#     'y': '37.537114070206634',
#     'zip_code': ''},
#    'address_name': '서울 마포구 마포동',
#    'address_type': 'REGION',
#    'road_address': None,
#    'x': '126.94382545190385',
#    'y': '37.537114070206634'}],
#  'meta': {'is_end': True, 'pageable_count': 1, 'total_count': 1}}

# %% [markdown]
# ## 공공데이터 포털 링크들
#
# 1. https://www.data.go.kr/dataset/3053773/fileData.do
#
# 2. http://data.seoul.go.kr/dataList/datasetView.do?infId=OA-13288&srvType=F&serviceKind=1&currentPageNo=1
#
# 3.

# %% [markdown]
# ## 유동인구 csv 파일 읽어오기

# %%
import pandas as pd

foot_traffic_df = pd.read_csv("자치구단위 서울 생활인구(내국인).csv")

foot_traffic_df
# Out:
#            기준일ID  시간대구분  자치구코드       총생활인구수  남자0세부터9세생활인구수  남자10세부터14세생활인구수  \
# 0       20191014      0  11110  218486.6054      5272.4296        3149.0623
# 1       20191014      0  11140  180523.0699      3484.9634        1477.7794
# 2       20191014      0  11170  259142.1005      7190.7354        3581.9286
# 3       20191014      0  11200  341338.8497     12202.6810        5282.9766
# 4       20191014      0  11215  386867.4233     11634.4287        6303.3485
# 5       20191014      0  11230  368393.7632     11080.8869        5549.5631
# 6       20191014      0  11260  383757.2989     13729.8559        6647.2314
# 7       20191014      0  11290  463398.0651     17822.7665        9987.3387
# 8       20191014      0  11305  334037.3883     10616.4054        5825.5041
# 9       20191014      0  11320  289947.7740      9996.0473        5550.5080
# 10      20191014      0  11350  569496.6964     20630.4087       13732.7062
# ...

# %%
mapping_code_df = pd.read_excel("행정동코드_매핑정보_2018.xlsx")

mapping_code_df
# Out:
#       통계청행정동코드  행자부행정동코드    시도명   시군구명         행정동명
# 0    H_SDNG_CD  H_DNG_CD  DO_NM  CT_NM     H_DNG_NM
# 1      1101053  11110530     서울    종로구          사직동
# 2      1101054  11110540     서울    종로구          삼청동
# 3      1101055  11110550     서울    종로구          부암동
# 4      1101056  11110560     서울    종로구          평창동
# 5      1101057  11110570     서울    종로구          무악동
# 6      1101058  11110580     서울    종로구          교남동
# 7      1101060  11110600     서울    종로구          가회동
# 8      1101061  11110615     서울    종로구  종로1.2.3.4가동
# 9      1101063  11110630     서울    종로구      종로5.6가동
# 10     1101064  11110640     서울    종로구          이화동
# 11     1101067  11110670     서울    종로구         창신1동
# 12     1101068  11110680     서울    종로구         창신2동
# 13     1101069  11110690     서울    종로구         창신3동
# 14     1101070  11110700     서울    종로구         숭인1동
# 15     1101071  11110710     서울    종로구         숭인2동
# 16     1101072  11110515     서울    종로구        청운효자동
# ...
